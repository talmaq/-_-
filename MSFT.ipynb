# %%
# dataset @ https://uk.finance.yahoo.com/quote/MSFT/history/

# %%
import pandas as pd

df = pd.read_csv('MSFT.csv')

df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060163
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062311
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063386
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.061774
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.060700
# ...          ...         ...         ...         ...         ...         ...
# 9583  2024-03-22  429.700012  429.859985  426.070007  428.739990  428.739990
# 9584  2024-03-25  425.239990  427.410004  421.609985  422.859985  422.859985
# 9585  2024-03-26  425.609985  425.989990  421.350006  421.649994  421.649994
# 9586  2024-03-27  424.440002  424.450012  419.010010  421.429993  421.429993
# 9587  2024-03-28  420.959991  421.869995  419.119995  420.720001  420.720001
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9583    17636500
# 9584    18060500
# 9585    16725600
# 9586    16705000
# 9587    21871200
#
# [9588 rows x 7 columns]

# %%
df = df[['Date', 'Close']]

df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9583  2024-03-22  428.739990
# 9584  2024-03-25  422.859985
# 9585  2024-03-26  421.649994
# 9586  2024-03-27  421.429993
# 9587  2024-03-28  420.720001
#
# [9588 rows x 2 columns]

# %%
df['Date']
# Out:
# 0       1986-03-13
# 1       1986-03-14
# 2       1986-03-17
# 3       1986-03-18
# 4       1986-03-19
#            ...
# 9583    2024-03-22
# 9584    2024-03-25
# 9585    2024-03-26
# 9586    2024-03-27
# 9587    2024-03-28
# Name: Date, Length: 9588, dtype: object

# %%
import datetime

def str_to_datetime(s):
    split = s.split('-')
    year, month, day = int(split[0]), int(split[1]), int(split[2])
    return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9583  2024-03-22  428.739990
# 9584  2024-03-25  422.859985
# 9585  2024-03-26  421.649994
# 9586  2024-03-27  421.429993
# 9587  2024-03-28  420.720001
#
# [9588 rows x 2 columns]

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# C:\Users\Maqso\AppData\Local\Temp\ipykernel_16312\2565755782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9583   2024-03-22
# 9584   2024-03-25
# 9585   2024-03-26
# 9586   2024-03-27
# 9587   2024-03-28
# Name: Date, Length: 9588, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2024-03-22  428.739990
# 2024-03-25  422.859985
# 2024-03-26  421.649994
# 2024-03-27  421.429993
# 2024-03-28  420.720001
#
# [9588 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
    first_date = str_to_datetime(first_date_str)
    last_date  = str_to_datetime(last_date_str)
    target_date = first_date

    dates = []
    X, Y = [], []
    last_time = False
    while True:
       df_subset = dataframe.loc[:target_date].tail(n+1)
       if len(df_subset) != n+1:
         print(f'Error: Window of size {n} is too large for date {target_date}')
         return
       
       values = df_subset['Close'].to_numpy()
       x, y = values[:-1], values[-1]
       dates.append(target_date)
       X.append(x)
       Y.append(y)
       
       next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
       next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
       next_date_str = next_datetime_str.split('T')[0]
       year_month_day = next_date_str.split('-')
       year, month, day = year_month_day
       next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
       
       if last_time:
        break
       
       target_date = next_date

       if target_date == last_date:
         last_time = True
    
    ret_df = pd.DataFrame({})
    ret_df['Target Date'] = dates
    
    X = np.array(X)
    for i in range(0, n):
       X[:, i]
       ret_df[f'Target-{n-i}'] = X[:, i]
       
    ret_df['Target'] = Y
    return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df, 
                                '2021-03-25', 
                                '2022-03-23', 
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  235.990005  237.580002  235.460007  232.339996
# 1    2021-03-26  237.580002  235.460007  232.339996  236.479996
# 2    2021-03-29  235.460007  232.339996  236.479996  235.240005
# 3    2021-03-30  232.339996  236.479996  235.240005  231.850006
# 4    2021-03-31  236.479996  235.240005  231.850006  235.770004
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 248  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 249  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 250  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 251  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [252 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)), 
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - loss: 84592.7891 - mean_absolute_error: 288.8488 - val_loss: 92290.6094 - val_mean_absolute_error: 303.7065
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 84384.0859 - mean_absolute_error: 288.6830 - val_loss: 91983.6172 - val_mean_absolute_error: 303.2007
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 82920.6562 - mean_absolute_error: 285.8232 - val_loss: 91624.0312 - val_mean_absolute_error: 302.6071
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 83933.3125 - mean_absolute_error: 287.8358 - val_loss: 91191.5312 - val_mean_absolute_error: 301.8916
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 83463.9688 - mean_absolute_error: 287.1461 - val_loss: 90583.1484 - val_mean_absolute_error: 300.8823
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 83719.9688 - mean_absolute_error: 287.3836 - val_loss: 89624.7891 - val_mean_absolute_error: 299.2855
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 83344.2109 - mean_absolute_error: 287.2713 - val_loss: 88589.2188 - val_mean_absolute_error: 297.5504
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 79401.7656 - mean_absolute_error: 279.5303 - val_loss: 87246.3828 - val_mean_absolute_error: 295.2853
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 78966.0234 - mean_absolute_error: 279.3415 - val_loss: 85770.0703 - val_mean_absolute_error: 292.7748
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 77880.7578 - mean_absolute_error: 277.1750 - val_loss: 84025.5078 - val_mean_absolute_error: 289.7801
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 75200.1328 - mean_absolute_error: 272.2119 - val_loss: 82012.0547 - val_mean_absolute_error: 286.2850
# Epoch 12/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 75224.1875 - mean_absolute_error: 272.2623 - val_loss: 79708.4141 - val_mean_absolute_error: 282.2329
# Epoch 13/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 71652.3047 - mean_absolute_error: 265.4144 - val_loss: 76897.6328 - val_mean_absolute_error: 277.2085
# Epoch 14/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 68135.4062 - mean_absolute_error: 259.1243 - val_loss: 73188.9375 - val_mean_absolute_error: 270.4365
# Epoch 15/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 64794.8203 - mean_absolute_error: 252.5137 - val_loss: 69452.5078 - val_mean_absolute_error: 263.4379
# Epoch 16/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 61589.2148 - mean_absolute_error: 245.9990 - val_loss: 65200.8164 - val_mean_absolute_error: 255.2404
# Epoch 17/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 58637.2969 - mean_absolute_error: 240.3543 - val_loss: 60412.3164 - val_mean_absolute_error: 245.6814
# Epoch 18/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 53825.7930 - mean_absolute_error: 229.6056 - val_loss: 55467.6562 - val_mean_absolute_error: 235.4031
# Epoch 19/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 49040.0859 - mean_absolute_error: 219.0087 - val_loss: 50179.6133 - val_mean_absolute_error: 223.8898
# Epoch 20/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 43086.4492 - mean_absolute_error: 205.3074 - val_loss: 44894.8555 - val_mean_absolute_error: 211.7589
# Epoch 21/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 38785.7305 - mean_absolute_error: 194.4214 - val_loss: 38903.6133 - val_mean_absolute_error: 197.1057
# Epoch 22/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 32627.8457 - mean_absolute_error: 178.1049 - val_loss: 33376.8008 - val_mean_absolute_error: 182.5482
# Epoch 23/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 28545.0137 - mean_absolute_error: 166.1014 - val_loss: 28110.9121 - val_mean_absolute_error: 167.5051
# Epoch 24/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 23134.8906 - mean_absolute_error: 148.9316 - val_loss: 23145.3770 - val_mean_absolute_error: 151.9619
# Epoch 25/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 18680.8184 - mean_absolute_error: 132.5043 - val_loss: 18555.7031 - val_mean_absolute_error: 136.0246
# Epoch 26/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 14321.7246 - mean_absolute_error: 115.8675 - val_loss: 14050.8838 - val_mean_absolute_error: 118.3129
# Epoch 27/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 10675.5703 - mean_absolute_error: 98.0375 - val_loss: 10434.2695 - val_mean_absolute_error: 101.8887
# Epoch 28/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7724.3340 - mean_absolute_error: 82.5662 - val_loss: 7498.1001 - val_mean_absolute_error: 86.2852
# Epoch 29/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5600.7305 - mean_absolute_error: 67.5776 - val_loss: 5200.2642 - val_mean_absolute_error: 71.7434
# Epoch 30/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3520.8418 - mean_absolute_error: 51.1496 - val_loss: 3400.0837 - val_mean_absolute_error: 57.8543
# Epoch 31/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2546.5615 - mean_absolute_error: 40.5182 - val_loss: 2225.3943 - val_mean_absolute_error: 46.6093
# Epoch 32/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1818.7748 - mean_absolute_error: 35.1163 - val_loss: 1430.3939 - val_mean_absolute_error: 37.1137
# Epoch 33/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1353.9768 - mean_absolute_error: 30.1494 - val_loss: 939.2996 - val_mean_absolute_error: 29.7714
# Epoch 34/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1266.8938 - mean_absolute_error: 30.5514 - val_loss: 619.4882 - val_mean_absolute_error: 23.8017
# Epoch 35/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1043.4691 - mean_absolute_error: 27.2669 - val_loss: 440.5773 - val_mean_absolute_error: 19.6879
# Epoch 36/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1124.1036 - mean_absolute_error: 28.8603 - val_loss: 337.2650 - val_mean_absolute_error: 16.8612
# Epoch 37/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1036.3682 - mean_absolute_error: 27.5746 - val_loss: 291.9678 - val_mean_absolute_error: 15.4807
# Epoch 38/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1061.4939 - mean_absolute_error: 27.7383 - val_loss: 269.5379 - val_mean_absolute_error: 14.7969
# Epoch 39/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 981.5433 - mean_absolute_error: 26.3997 - val_loss: 249.6804 - val_mean_absolute_error: 14.1613
# Epoch 40/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1059.2379 - mean_absolute_error: 27.9248 - val_loss: 248.2709 - val_mean_absolute_error: 14.1150
# Epoch 41/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 970.9696 - mean_absolute_error: 25.9891 - val_loss: 245.7929 - val_mean_absolute_error: 14.0332
# Epoch 42/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1116.2389 - mean_absolute_error: 28.7970 - val_loss: 252.7602 - val_mean_absolute_error: 14.2619
# Epoch 43/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1051.3462 - mean_absolute_error: 27.4890 - val_loss: 273.0168 - val_mean_absolute_error: 14.9052
# Epoch 44/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1028.8295 - mean_absolute_error: 27.0629 - val_loss: 274.9126 - val_mean_absolute_error: 14.9639
# Epoch 45/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1075.0187 - mean_absolute_error: 27.6754 - val_loss: 278.5725 - val_mean_absolute_error: 15.0764
# Epoch 46/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 999.7799 - mean_absolute_error: 26.3973 - val_loss: 281.3286 - val_mean_absolute_error: 15.1606
# Epoch 47/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1026.6659 - mean_absolute_error: 26.8576 - val_loss: 279.0177 - val_mean_absolute_error: 15.0901
# Epoch 48/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 906.5522 - mean_absolute_error: 24.8038 - val_loss: 274.9812 - val_mean_absolute_error: 14.9660
# Epoch 49/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 957.5560 - mean_absolute_error: 26.3309 - val_loss: 271.7201 - val_mean_absolute_error: 14.8650
# Epoch 50/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 950.9077 - mean_absolute_error: 25.5918 - val_loss: 272.5077 - val_mean_absolute_error: 14.8895
# Epoch 51/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 969.7615 - mean_absolute_error: 26.3077 - val_loss: 274.6211 - val_mean_absolute_error: 14.9551
# Epoch 52/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1031.6455 - mean_absolute_error: 27.2564 - val_loss: 299.5619 - val_mean_absolute_error: 15.7211
# Epoch 53/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1017.6030 - mean_absolute_error: 27.2356 - val_loss: 338.4492 - val_mean_absolute_error: 16.9277
# Epoch 54/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 973.9693 - mean_absolute_error: 26.0668 - val_loss: 410.0918 - val_mean_absolute_error: 18.9950
# Epoch 55/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1059.2344 - mean_absolute_error: 27.7365 - val_loss: 230.1116 - val_mean_absolute_error: 13.5200
# Epoch 56/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 968.2372 - mean_absolute_error: 26.7356 - val_loss: 401.7812 - val_mean_absolute_error: 18.7506
# Epoch 57/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1022.2584 - mean_absolute_error: 27.5056 - val_loss: 302.4487 - val_mean_absolute_error: 15.8809
# Epoch 58/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 873.0657 - mean_absolute_error: 24.8228 - val_loss: 278.0415 - val_mean_absolute_error: 15.1230
# Epoch 59/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 896.4403 - mean_absolute_error: 25.6486 - val_loss: 272.4609 - val_mean_absolute_error: 14.9595
# Epoch 60/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 935.1675 - mean_absolute_error: 26.0043 - val_loss: 290.8551 - val_mean_absolute_error: 15.5625
# Epoch 61/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 828.6775 - mean_absolute_error: 23.9725 - val_loss: 275.4412 - val_mean_absolute_error: 15.0714
# Epoch 62/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 848.7221 - mean_absolute_error: 24.4841 - val_loss: 239.0915 - val_mean_absolute_error: 13.9228
# Epoch 63/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 887.2675 - mean_absolute_error: 25.4293 - val_loss: 308.8444 - val_mean_absolute_error: 16.1948
# Epoch 64/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 801.7506 - mean_absolute_error: 23.7540 - val_loss: 152.1573 - val_mean_absolute_error: 10.5984
# Epoch 65/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 733.9092 - mean_absolute_error: 22.2365 - val_loss: 306.6223 - val_mean_absolute_error: 16.1803
# Epoch 66/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 793.7153 - mean_absolute_error: 24.2351 - val_loss: 799.9164 - val_mean_absolute_error: 27.5141
# Epoch 67/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 766.9487 - mean_absolute_error: 23.6546 - val_loss: 219.7815 - val_mean_absolute_error: 13.3591
# Epoch 68/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 709.3186 - mean_absolute_error: 22.7621 - val_loss: 134.7157 - val_mean_absolute_error: 9.9252
# Epoch 69/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 645.8761 - mean_absolute_error: 21.6336 - val_loss: 368.9094 - val_mean_absolute_error: 18.1330
# Epoch 70/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 567.5836 - mean_absolute_error: 19.8055 - val_loss: 121.1829 - val_mean_absolute_error: 9.3083
# Epoch 71/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 611.6921 - mean_absolute_error: 20.8453 - val_loss: 75.5644 - val_mean_absolute_error: 7.0280
# Epoch 72/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 569.9510 - mean_absolute_error: 20.4909 - val_loss: 203.1635 - val_mean_absolute_error: 12.8770
# Epoch 73/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 484.4413 - mean_absolute_error: 18.2385 - val_loss: 241.5228 - val_mean_absolute_error: 14.3245
# Epoch 74/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 413.6237 - mean_absolute_error: 16.8099 - val_loss: 90.7285 - val_mean_absolute_error: 7.9051
# Epoch 75/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 404.8870 - mean_absolute_error: 16.3062 - val_loss: 51.7106 - val_mean_absolute_error: 5.6812
# Epoch 76/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 403.1128 - mean_absolute_error: 17.0143 - val_loss: 49.0473 - val_mean_absolute_error: 5.5418
# Epoch 77/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 304.8322 - mean_absolute_error: 14.5803 - val_loss: 74.5585 - val_mean_absolute_error: 7.0768
# Epoch 78/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 289.6235 - mean_absolute_error: 13.4426 - val_loss: 58.2427 - val_mean_absolute_error: 6.1488
# Epoch 79/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 248.0845 - mean_absolute_error: 12.5949 - val_loss: 44.2862 - val_mean_absolute_error: 5.3850
# Epoch 80/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 213.8945 - mean_absolute_error: 12.0318 - val_loss: 81.1726 - val_mean_absolute_error: 7.5179
# Epoch 81/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 197.1950 - mean_absolute_error: 10.7137 - val_loss: 38.1226 - val_mean_absolute_error: 5.2077
# Epoch 82/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 158.4025 - mean_absolute_error: 10.0250 - val_loss: 46.8634 - val_mean_absolute_error: 5.6098
# Epoch 83/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 142.8573 - mean_absolute_error: 9.1779 - val_loss: 41.6353 - val_mean_absolute_error: 5.3748
# Epoch 84/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 111.4973 - mean_absolute_error: 8.0036 - val_loss: 30.7197 - val_mean_absolute_error: 4.9029
# Epoch 85/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 95.5578 - mean_absolute_error: 7.3715 - val_loss: 62.1627 - val_mean_absolute_error: 6.5970
# Epoch 86/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 84.0422 - mean_absolute_error: 6.8234 - val_loss: 43.3978 - val_mean_absolute_error: 5.2982
# Epoch 87/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 69.0283 - mean_absolute_error: 6.6714 - val_loss: 66.0092 - val_mean_absolute_error: 6.5217
# Epoch 88/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 64.1582 - mean_absolute_error: 6.4933 - val_loss: 30.7774 - val_mean_absolute_error: 4.8261
# Epoch 89/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 45.7384 - mean_absolute_error: 4.9547 - val_loss: 32.4061 - val_mean_absolute_error: 4.8359
# Epoch 90/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 42.3967 - mean_absolute_error: 4.9850 - val_loss: 59.9469 - val_mean_absolute_error: 6.1695
# Epoch 91/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 42.5219 - mean_absolute_error: 5.2089 - val_loss: 32.4927 - val_mean_absolute_error: 4.8332
# Epoch 92/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 35.8911 - mean_absolute_error: 4.5506 - val_loss: 48.3843 - val_mean_absolute_error: 5.5561
# Epoch 93/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 32.3018 - mean_absolute_error: 4.4894 - val_loss: 42.5381 - val_mean_absolute_error: 5.2411
# Epoch 94/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 34.4606 - mean_absolute_error: 4.5091 - val_loss: 38.4446 - val_mean_absolute_error: 4.9971
# Epoch 95/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 28.7104 - mean_absolute_error: 4.3357 - val_loss: 38.8227 - val_mean_absolute_error: 5.0204
# Epoch 96/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 24.5851 - mean_absolute_error: 3.7877 - val_loss: 36.9854 - val_mean_absolute_error: 4.9207
# Epoch 97/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 26.1341 - mean_absolute_error: 3.9900 - val_loss: 105.1042 - val_mean_absolute_error: 8.6859
# Epoch 98/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 42.0694 - mean_absolute_error: 5.3338 - val_loss: 43.8355 - val_mean_absolute_error: 5.6340
# Epoch 99/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 36.3023 - mean_absolute_error: 4.9260 - val_loss: 49.8238 - val_mean_absolute_error: 5.6984
# Epoch 100/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 23.6483 - mean_absolute_error: 3.9163 - val_loss: 54.5742 - val_mean_absolute_error: 5.9474

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])
